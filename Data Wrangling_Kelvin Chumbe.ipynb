# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
# set display options
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 300)

# %%
# read in the data
train = pd.read_csv("https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv")

# %%
train.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
train.shape
# Out:
# (29523, 11)

# %%
new_df = train.groupby(by="fuel_type_code_pudl")["fuel_cost_per_unit_burned"].agg(["mean"]).sort_values(by="mean", ascending=True)

# %%
new_df
# Out:
#                             mean
# fuel_type_code_pudl
# gas                    13.659397
# other                  18.253856
# waste                  19.518122
# coal                   67.421830
# oil                   168.877086
# nuclear              4955.157002

# %%
# standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places?

percentile_75 = train["fuel_mmbtu_per_unit"].quantile(.75)
std = train["fuel_mmbtu_per_unit"].std()

# %%
percentile_75, std
# Out:
# (17.006, 10.600220307806886)

# %%
# skewness and kurtosis for the fuel quantity burned 
train["fuel_qty_burned"].skew(), train["fuel_qty_burned"].kurt()
# Out:
# (15.851495469109503, 651.3694501337732)

# %%
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places? 
# (Enter answer in the format: Feature: xxx, Total: xxx, Percent: xxx)

total_null = train.isnull().sum()[tr
                                  ain.isnull().sum() > 0]
percentage = total_null / train.shape[0] * 100

pd.concat([total_null, percentage], axis=1, keys=["Total_Missing_Values", "Percentage"])
# Out:
#            Total_Missing_Values  Percentage
# fuel_unit                   180    0.609694

# %%
-0.000437 > -0.037863
# Out:
# True

# %%
-0.01 < -0.001
# Out:
# True

# %%
# features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?
(train.corr())["fuel_cost_per_unit_burned"].sort_values(ascending=False)
# Out:
# fuel_cost_per_unit_burned       1.000000
# report_year                     0.013599
# fuel_cost_per_unit_delivered    0.011007
# fuel_cost_per_mmbtu            -0.000437
# fuel_mmbtu_per_unit            -0.010034
# fuel_qty_burned                -0.018535
# utility_id_ferc1               -0.037863
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# For the fuel type coal, what is the percentage change in the fuel cost per unit burned in 1998 compared to 1994?
df = train.groupby(by=["report_year", "fuel_type_code_pudl"])["fuel_cost_per_unit_burned"].mean().reset_index()

# %%
df
# Out:
#      report_year fuel_type_code_pudl  fuel_cost_per_unit_burned
# 0           1994                coal                  31.546467
# 1           1994                 gas                  22.161183
# 2           1994             nuclear                3211.033155
# 3           1994                 oil                  56.398759
# 4           1994               other                   9.728083
# 5           1994               waste                   2.198417
# 6           1995                coal                  30.677442
# 7           1995                 gas                  18.067406
# 8           1995             nuclear                5262.364918
# 9           1995                 oil                 158.037885
# 10          1995               other                  12.238467
# 11          1995               waste                  -8.759045
# 12          1996                coal                  29.454299
# 13          1996                 gas                   3.444577
# ...

# %%
df = df[df["fuel_type_code_pudl"] == "coal"]
df
# Out:
#      report_year fuel_type_code_pudl  fuel_cost_per_unit_burned
# 0           1994                coal                  31.546467
# 6           1995                coal                  30.677442
# 12          1996                coal                  29.454299
# 18          1997                coal                 104.897309
# 24          1998                coal                  27.616234
# 30          1999                coal                  38.361101
# 36          2000                coal                 249.203055
# 42          2001                coal                  41.622623
# 48          2002                coal                  27.623988
# 54          2003                coal                  94.085441
# 60          2004                coal                  29.913239
# 66          2005                coal                  34.281426
# 72          2006                coal                  37.928697
# 78          2007                coal                  39.288397
# ...

# %%
fuel_burned_1994 = df[df["report_year"] == 1994]["fuel_cost_per_unit_burned"].values[0]
fuel_burned_1998 = df[df["report_year"] == 1998]["fuel_cost_per_unit_burned"].values[0]

# %%
change = (fuel_burned_1998 - fuel_burned_1994) / fuel_burned_1994 * 100

# %%
fuel_burned_1998 ,fuel_burned_1994
# Out:
# (27.61623433874713, 31.546467368421077)

# %%
change
# Out:
# -12.458551963280119

# %%
train.groupby(by="report_year")["fuel_cost_per_unit_delivered"].mean().sort_values(ascending=False)
# Out:
# report_year
# 1997    11140.197239
# 1996     9196.705948
# 2000      985.362877
# 2009      652.694163
# 2018      499.269966
# 2015      326.535511
# 1998      287.154420
# 2014      192.737183
# 2013      172.307591
# 2004      139.524275
# 2016      103.901761
# 2010       91.862105
# 1994       63.636060
# 2012       60.994502
# 2001       60.050396
# 2011       59.774667
# 2008       58.588197
# 2003       55.663493
# 2002       47.594361
# 2017       46.196861
# 2007       43.325023
# 2005       41.438184
# 2006       38.657484
# 1995       32.735269
# 1999       25.551627
# Name: fuel_cost_per_unit_delivered, dtype: float64
